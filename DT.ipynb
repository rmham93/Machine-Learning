# %% [markdown]
# # ML HW2 Decision Trees
# ### Fatma Ridaoui 1950044013

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataDf = pd.read_csv('abalone.data',sep=",")

# %%
col_names =["Sex","Length","Diameter","Height","Whole weight","Shucked weight","Viscera weight","Shell weight","Rings"]

# %%
dataDf.head()
# Out:
#    M  0.455  0.365  0.095   0.514  0.2245   0.101   0.15  15
# 0  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 1  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 2  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 3  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7
# 4  I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.120   8

# %%
dataDf.columns = col_names

# %%
dataDf.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 1   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 2   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 3   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 4   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
#
#    Shell weight  Rings
# 0         0.070      7
# 1         0.210      9
# 2         0.155     10
# 3         0.055      7
# 4         0.120      8

# %%
data = np.array(dataDf)

# %%
def findUnique(rows,col):
    #find classes in dataset from label col
    return set([row[col] for row in rows])

# %%
#findUnique(data,-1) #CLASS 1-29

# %%
def attribute_find(data):
    attribute_types = []

    for each in data:
        if isinstance(each, int) or isinstance(each, float):
            attribute_types.append(1)
        else:
            attribute_types.append(2) #categorical
    return attribute_types

# %%
X = dataDf.drop("Rings",1)
y = dataDf["Rings"]
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size= 0.2)

# %%
"""We will need for impurity
Counts the number of each type of example in a dataset."""
def class_counts(rows):
    counts = {} 
    for row in rows:
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
class_counts(data)
# Out:
# {7: 391,
#  9: 689,
#  10: 634,
#  8: 568,
#  20: 26,
#  16: 67,
#  19: 32,
#  14: 126,
#  11: 487,
#  12: 267,
#  15: 102,
#  18: 42,
#  13: 203,
#  5: 115,
#  4: 57,
#  6: 259,
#  21: 14,
#  17: 58,
#  22: 6,
#  1: 1,
#  3: 15,
#  26: 1,
#  23: 9,
#  29: 1,
#  2: 1,
#  27: 2,
#  25: 1,
#  24: 2}

# %%
attribute_types =attribute_find(data)

# %%
class Question:
    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            col_names[self.column], condition, str(self.value))

# %%
def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

# %% [markdown]
# ## Decision Tree

# %%
class Leaf:
    def __init__(self,rows):
        self.pred = class_counts(rows)

# %%
class DecisionNode:
    def __init__(self, quest,true,false):
        self.question = quest
        self.true = true
        self.false = false

# %%
def info_gain(left, right, current_uncertainty):

    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
def gini(rows):

    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
def partition(rows, question):

    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
def find_best_modeling_dt(rows):
 
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  

        for val in values:  # for each value

            question = Question(col, val)

            # try splitting the dataset
            true_rows, false_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(true_rows, false_rows, current_uncertainty)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain >= best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

# %%
def build_dt(X,y,attribute_types, options):
    # returns a decision tree
    gain, question = find_best_modeling_dt(X)
    if gain ==0:
        return Leaf(X)
    
    true_rows, false_rows = partition(X, question)
    
    true = build_dt(true_rows,y,attribute_types,options)
    false = build_dt(false_rows, y, attribute_types,options)
    
    return DecisionNode(question, true, false)

# %%
X_train = np.array(X_train)
dt = build_dt(X_train,y_train,attribute_types,0)

# %% [markdown]
# ### Predict

# %%
def predict_dt(row, node):
    
    if isinstance(node, Leaf):
        return node.pred

    if node.question.match(row):
        return predict_dt(row, node.true)
    else:
        return predict_dt(row, node.false)

# %%
X_test = np.array(X_test)
predict_dt(X_test[0], dt)
# Out:
# {0.35: 1}

# %%
def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %%
print_leaf(predict_dt(X_test[0], dt))
# Out:
# {0.35: '100%'}

# %%
for idx, row in enumerate(X_test): 
    print ("Actual: %s. Predicted: %s" %
           (y[idx], print_leaf(predict_dt(row, dt))))
#Predicted will be changed, mistake printed
# Out:
# Actual: 7. Predicted: {0.35: '100%'}
# Actual: 9. Predicted: {0.0215: '100%'}
# Actual: 10. Predicted: {0.255: '100%'}
# Actual: 7. Predicted: {0.14300000000000002: '100%'}
# Actual: 8. Predicted: {0.425: '100%'}
# Actual: 20. Predicted: {0.185: '100%'}
# Actual: 16. Predicted: {0.053: '100%'}
# Actual: 9. Predicted: {0.26: '100%'}
# Actual: 19. Predicted: {0.1: '100%'}
# Actual: 14. Predicted: {0.1845: '100%'}
# Actual: 10. Predicted: {0.11: '100%'}
# Actual: 11. Predicted: {0.14300000000000002: '100%'}
# Actual: 10. Predicted: {0.275: '100%'}
# Actual: 10. Predicted: {0.215: '100%'}
# Actual: 12. Predicted: {0.053: '100%'}
# Actual: 7. Predicted: {0.4395: '100%'}
# Actual: 10. Predicted: {0.1945: '100%'}
# Actual: 7. Predicted: {0.115: '100%'}
# Actual: 9. Predicted: {0.469: '100%'}
# Actual: 11. Predicted: {0.195: '100%'}
# Actual: 10. Predicted: {0.22: '100%'}
# Actual: 12. Predicted: {0.235: '100%'}
# Actual: 9. Predicted: {0.3: '100%'}
# Actual: 10. Predicted: {0.09: '100%'}
# Actual: 11. Predicted: {0.161: '100%'}
# Actual: 11. Predicted: {0.32: '100%'}
# Actual: 12. Predicted: {0.255: '100%'}
# Actual: 15. Predicted: {0.235: '100%'}
# Actual: 11. Predicted: {0.27: '100%'}
# Actual: 10. Predicted: {0.26: '100%'}
# Actual: 15. Predicted: {0.32: '100%'}
# Actual: 18. Predicted: {0.725: '100%'}
# Actual: 19. Predicted: {0.35: '100%'}
# Actual: 13. Predicted: {0.255: '100%'}
# Actual: 8. Predicted: {0.3: '100%'}
# Actual: 16. Predicted: {0.325: '100%'}
# Actual: 8. Predicted: {0.2725: '100%'}
# Actual: 11. Predicted: {0.355: '100%'}
# Actual: 9. Predicted: {0.245: '100%'}
# Actual: 9. Predicted: {0.78: '100%'}
# Actual: 14. Predicted: {0.535: '100%'}
# Actual: 5. Predicted: {0.14800000000000002: '100%'}
# Actual: 5. Predicted: {0.135: '100%'}
# Actual: 4. Predicted: {0.196: '100%'}
# Actual: 7. Predicted: {0.05: '100%'}
# Actual: 9. Predicted: {0.155: '100%'}
# Actual: 7. Predicted: {0.03: '100%'}
# Actual: 6. Predicted: {0.37: '100%'}
# Actual: 9. Predicted: {0.1495: '100%'}
# Actual: 8. Predicted: {0.58: '100%'}
# Actual: 7. Predicted: {0.4245: '100%'}
# Actual: 10. Predicted: {0.149: '100%'}
# Actual: 10. Predicted: {0.115: '100%'}
# Actual: 7. Predicted: {0.25: '100%'}
# Actual: 8. Predicted: {0.255: '100%'}
# Actual: 8. Predicted: {0.31: '100%'}
# Actual: 8. Predicted: {0.265: '100%'}
# Actual: 4. Predicted: {0.105: '100%'}
# Actual: 7. Predicted: {0.1785: '100%'}
# Actual: 7. Predicted: {0.045: '100%'}
# Actual: 9. Predicted: {0.09: '100%'}
# Actual: 10. Predicted: {0.385: '100%'}
# Actual: 7. Predicted: {0.159: '100%'}
# Actual: 8. Predicted: {0.23600000000000002: '100%'}
# Actual: 8. Predicted: {0.12: '100%'}
# Actual: 12. Predicted: {0.245: '100%'}
# Actual: 13. Predicted: {0.13: '100%'}
# Actual: 10. Predicted: {0.4075: '100%'}
# Actual: 6. Predicted: {0.29: '100%'}
# Actual: 13. Predicted: {0.345: '100%'}
# Actual: 8. Predicted: {0.4405: '100%'}
# Actual: 20. Predicted: {0.165: '100%'}
# Actual: 11. Predicted: {0.24: '100%'}
# Actual: 13. Predicted: {0.32: '100%'}
# Actual: 15. Predicted: {0.363: '100%'}
# Actual: 9. Predicted: {0.26899999999999996: '100%'}
# Actual: 10. Predicted: {0.05: '100%'}
# Actual: 11. Predicted: {0.2505: '100%'}
# Actual: 14. Predicted: {0.1555: '100%'}
# Actual: 9. Predicted: {0.045: '100%'}
# Actual: 12. Predicted: {0.09300000000000001: '100%'}
# Actual: 16. Predicted: {0.042: '100%'}
# Actual: 21. Predicted: {0.42: '100%'}
# Actual: 14. Predicted: {0.315: '100%'}
# Actual: 12. Predicted: {0.065: '100%'}
# Actual: 13. Predicted: {0.5: '100%'}
# Actual: 10. Predicted: {0.19: '100%'}
# Actual: 9. Predicted: {0.1135: '100%'}
# Actual: 12. Predicted: {0.09: '100%'}
# Actual: 15. Predicted: {0.23: '100%'}
# Actual: 12. Predicted: {0.0415: '100%'}
# Actual: 13. Predicted: {0.19: '100%'}
# Actual: 10. Predicted: {0.225: '100%'}
# Actual: 15. Predicted: {0.299: '100%'}
# Actual: 14. Predicted: {0.105: '100%'}
# Actual: 9. Predicted: {0.193: '100%'}
# Actual: 8. Predicted: {0.107: '100%'}
# Actual: 7. Predicted: {0.12: '100%'}
# Actual: 10. Predicted: {0.265: '100%'}
# Actual: 7. Predicted: {0.36: '100%'}
# Actual: 15. Predicted: {0.308: '100%'}
# Actual: 15. Predicted: {0.175: '100%'}
# Actual: 10. Predicted: {0.155: '100%'}
# Actual: 12. Predicted: {0.327: '100%'}
# Actual: 12. Predicted: {0.725: '100%'}
# Actual: 11. Predicted: {0.045: '100%'}
# Actual: 10. Predicted: {0.385: '100%'}
# Actual: 9. Predicted: {0.29: '100%'}
# Actual: 9. Predicted: {0.36: '100%'}
# Actual: 9. Predicted: {0.11: '100%'}
# Actual: 9. Predicted: {0.36: '100%'}
# Actual: 9. Predicted: {0.1845: '100%'}
# Actual: 9. Predicted: {0.0925: '100%'}
# Actual: 11. Predicted: {0.345: '100%'}
# Actual: 11. Predicted: {0.2475: '100%'}
# Actual: 11. Predicted: {0.28: '100%'}
# Actual: 10. Predicted: {0.38: '100%'}
# Actual: 9. Predicted: {0.158: '100%'}
# Actual: 8. Predicted: {0.37: '100%'}
# Actual: 9. Predicted: {0.15: '100%'}
# Actual: 7. Predicted: {0.335: '100%'}
# Actual: 14. Predicted: {0.335: '100%'}
# Actual: 6. Predicted: {0.1835: '100%'}
# Actual: 6. Predicted: {0.215: '100%'}
# Actual: 5. Predicted: {0.1765: '100%'}
# Actual: 6. Predicted: {0.239: '100%'}
# Actual: 8. Predicted: {0.115: '100%'}
# Actual: 19. Predicted: {0.111: '100%'}
# Actual: 18. Predicted: {0.285: '100%'}
# Actual: 17. Predicted: {0.4245: '100%'}
# Actual: 9. Predicted: {0.03: '100%'}
# Actual: 7. Predicted: {0.3: '100%'}
# Actual: 7. Predicted: {0.1345: '100%'}
# Actual: 7. Predicted: {0.0895: '100%'}
# Actual: 8. Predicted: {0.2755: '100%'}
# Actual: 7. Predicted: {0.3465: '100%'}
# Actual: 9. Predicted: {0.145: '100%'}
# Actual: 9. Predicted: {0.0575: '100%'}
# Actual: 9. Predicted: {0.10300000000000001: '100%'}
# Actual: 10. Predicted: {0.105: '100%'}
# Actual: 10. Predicted: {0.05: '100%'}
# Actual: 16. Predicted: {0.1645: '100%'}
# Actual: 11. Predicted: {0.465: '100%'}
# Actual: 10. Predicted: {0.245: '100%'}
# Actual: 10. Predicted: {0.209: '100%'}
# Actual: 10. Predicted: {0.355: '100%'}
# Actual: 9. Predicted: {0.13: '100%'}
# Actual: 5. Predicted: {0.415: '100%'}
# Actual: 4. Predicted: {0.20600000000000002: '100%'}
# Actual: 15. Predicted: {0.16: '100%'}
# Actual: 9. Predicted: {0.115: '100%'}
# Actual: 10. Predicted: {0.45: '100%'}
# Actual: 10. Predicted: {0.1: '100%'}
# Actual: 12. Predicted: {0.0505: '100%'}
# Actual: 10. Predicted: {0.02: '100%'}
# Actual: 13. Predicted: {0.145: '100%'}
# Actual: 16. Predicted: {0.3095: '100%'}
# Actual: 13. Predicted: {0.4715: '100%'}
# Actual: 13. Predicted: {0.0615: '100%'}
# Actual: 13. Predicted: {0.009000000000000001: '100%'}
# Actual: 13. Predicted: {0.52: '100%'}
# Actual: 12. Predicted: {0.012: '100%'}
# Actual: 18. Predicted: {0.26: '100%'}
# Actual: 16. Predicted: {0.335: '100%'}
# Actual: 14. Predicted: {0.126: '100%'}
# Actual: 20. Predicted: {0.34299999999999997: '100%'}
# Actual: 20. Predicted: {0.0245: '100%'}
# Actual: 14. Predicted: {0.264: '100%'}
# Actual: 12. Predicted: {0.345: '100%'}
# Actual: 14. Predicted: {0.27399999999999997: '100%'}
# Actual: 7. Predicted: {0.18600000000000003: '100%'}
# Actual: 8. Predicted: {0.225: '100%'}
# Actual: 8. Predicted: {0.055: '100%'}
# Actual: 5. Predicted: {0.76: '100%'}
# Actual: 7. Predicted: {0.285: '100%'}
# Actual: 5. Predicted: {0.5235: '100%'}
# Actual: 8. Predicted: {0.4405: '100%'}
# Actual: 4. Predicted: {0.05: '100%'}
# Actual: 11. Predicted: {0.18: '100%'}
# Actual: 14. Predicted: {0.245: '100%'}
# Actual: 21. Predicted: {0.405: '100%'}
# Actual: 10. Predicted: {0.004: '100%'}
# Actual: 10. Predicted: {0.045: '100%'}
# Actual: 12. Predicted: {0.345: '100%'}
# Actual: 13. Predicted: {0.175: '100%'}
# Actual: 12. Predicted: {0.41: '100%'}
# Actual: 10. Predicted: {0.355: '100%'}
# Actual: 11. Predicted: {0.2295: '100%'}
# Actual: 9. Predicted: {0.3085: '100%'}
# Actual: 13. Predicted: {0.1825: '100%'}
# Actual: 12. Predicted: {0.39899999999999997: '100%'}
# Actual: 14. Predicted: {0.365: '100%'}
# Actual: 8. Predicted: {0.305: '100%'}
# Actual: 10. Predicted: {0.065: '100%'}
# Actual: 12. Predicted: {0.6095: '100%'}
# Actual: 11. Predicted: {0.113: '100%'}
# Actual: 16. Predicted: {0.25: '100%'}
# Actual: 15. Predicted: {0.22: '100%'}
# Actual: 10. Predicted: {0.055: '100%'}
# Actual: 9. Predicted: {0.2065: '100%'}
# Actual: 13. Predicted: {0.235: '100%'}
# Actual: 12. Predicted: {0.7975: '100%'}
# Actual: 13. Predicted: {0.4325: '100%'}
# Actual: 8. Predicted: {0.055: '100%'}
# Actual: 9. Predicted: {0.3185: '100%'}
# Actual: 9. Predicted: {0.1805: '100%'}
# Actual: 8. Predicted: {0.1075: '100%'}
# Actual: 13. Predicted: {0.081: '100%'}
# Actual: 7. Predicted: {0.067: '100%'}
# Actual: 10. Predicted: {0.2455: '100%'}
# Actual: 7. Predicted: {0.375: '100%'}
# Actual: 12. Predicted: {0.12: '100%'}
# Actual: 9. Predicted: {0.09: '100%'}
# Actual: 14. Predicted: {0.57: '100%'}
# Actual: 10. Predicted: {0.105: '100%'}
# Actual: 8. Predicted: {0.43: '100%'}
# Actual: 7. Predicted: {0.135: '100%'}
# Actual: 10. Predicted: {0.0105: '100%'}
# Actual: 8. Predicted: {0.52: '100%'}
# Actual: 9. Predicted: {0.25: '100%'}
# Actual: 11. Predicted: {0.1515: '100%'}
# Actual: 9. Predicted: {0.29: '100%'}
# Actual: 11. Predicted: {0.33: '100%'}
# Actual: 10. Predicted: {0.345: '100%'}
# Actual: 9. Predicted: {0.07: '100%'}
# Actual: 7. Predicted: {0.008: '100%'}
# Actual: 7. Predicted: {0.055: '100%'}
# Actual: 11. Predicted: {0.175: '100%'}
# Actual: 15. Predicted: {0.496: '100%'}
# Actual: 13. Predicted: {0.1525: '100%'}
# Actual: 14. Predicted: {0.215: '100%'}
# Actual: 22. Predicted: {0.035: '100%'}
# Actual: 7. Predicted: {0.2035: '100%'}
# Actual: 12. Predicted: {0.4: '100%'}
# Actual: 9. Predicted: {0.2765: '100%'}
# Actual: 1. Predicted: {0.374: '100%'}
# Actual: 3. Predicted: {0.155: '100%'}
# Actual: 3. Predicted: {0.1725: '100%'}
# Actual: 5. Predicted: {0.2215: '100%'}
# Actual: 17. Predicted: {0.19: '100%'}
# Actual: 5. Predicted: {0.365: '100%'}
# Actual: 5. Predicted: {0.4525: '100%'}
# Actual: 8. Predicted: {0.005: '100%'}
# Actual: 8. Predicted: {0.435: '100%'}
# Actual: 10. Predicted: {0.055: '100%'}
# Actual: 13. Predicted: {0.17: '100%'}
# Actual: 9. Predicted: {0.153: '100%'}
# Actual: 7. Predicted: {0.43: '100%'}
# Actual: 7. Predicted: {0.195: '100%'}
# Actual: 7. Predicted: {0.5055: '100%'}
# Actual: 13. Predicted: {0.053: '100%'}
# Actual: 12. Predicted: {0.313: '100%'}
# Actual: 15. Predicted: {0.1: '100%'}
# Actual: 15. Predicted: {0.34: '100%'}
# Actual: 15. Predicted: {0.095: '100%'}
# Actual: 19. Predicted: {0.5755: '100%'}
# Actual: 10. Predicted: {0.0705: '100%'}
# Actual: 15. Predicted: {0.198: '100%'}
# Actual: 13. Predicted: {0.07: '100%'}
# Actual: 11. Predicted: {0.295: '100%'}
# Actual: 12. Predicted: {0.725: '100%'}
# Actual: 11. Predicted: {0.345: '100%'}
# Actual: 4. Predicted: {0.105: '100%'}
# Actual: 6. Predicted: {0.42200000000000004: '100%'}
# Actual: 11. Predicted: {0.26: '100%'}
# Actual: 14. Predicted: {0.325: '100%'}
# Actual: 8. Predicted: {0.248: '100%'}
# Actual: 9. Predicted: {0.281: '100%'}
# Actual: 13. Predicted: {0.135: '100%'}
# Actual: 22. Predicted: {0.03: '100%'}
# Actual: 16. Predicted: {0.17: '100%'}
# Actual: 14. Predicted: {0.474: '100%'}
# Actual: 15. Predicted: {0.042: '100%'}
# Actual: 13. Predicted: {0.2: '100%'}
# Actual: 22. Predicted: {0.49: '100%'}
# Actual: 12. Predicted: {0.025: '100%'}
# Actual: 18. Predicted: {0.15: '100%'}
# Actual: 20. Predicted: {0.1785: '100%'}
# Actual: 11. Predicted: {0.325: '100%'}
# Actual: 15. Predicted: {0.185: '100%'}
# Actual: 7. Predicted: {0.31: '100%'}
# Actual: 9. Predicted: {0.035: '100%'}
# Actual: 14. Predicted: {0.353: '100%'}
# Actual: 14. Predicted: {0.35: '100%'}
# Actual: 10. Predicted: {0.185: '100%'}
# Actual: 10. Predicted: {0.295: '100%'}
# Actual: 17. Predicted: {0.315: '100%'}
# Actual: 9. Predicted: {0.37: '100%'}
# Actual: 10. Predicted: {0.272: '100%'}
# Actual: 17. Predicted: {0.1725: '100%'}
# Actual: 12. Predicted: {0.35200000000000004: '100%'}
# Actual: 15. Predicted: {0.1: '100%'}
# Actual: 19. Predicted: {0.44: '100%'}
# Actual: 26. Predicted: {0.185: '100%'}
# Actual: 6. Predicted: {0.4535: '100%'}
# Actual: 6. Predicted: {0.275: '100%'}
# Actual: 4. Predicted: {0.1765: '100%'}
# Actual: 11. Predicted: {0.0425: '100%'}
# Actual: 9. Predicted: {0.223: '100%'}
# Actual: 9. Predicted: {0.3: '100%'}
# Actual: 13. Predicted: {0.115: '100%'}
# Actual: 8. Predicted: {0.235: '100%'}
# Actual: 6. Predicted: {0.3105: '100%'}
# Actual: 10. Predicted: {0.35: '100%'}
# Actual: 4. Predicted: {0.3535: '100%'}
# Actual: 3. Predicted: {0.6785: '100%'}
# Actual: 13. Predicted: {0.07: '100%'}
# Actual: 14. Predicted: {0.06: '100%'}
# Actual: 10. Predicted: {0.365: '100%'}
# Actual: 21. Predicted: {0.28300000000000003: '100%'}
# Actual: 14. Predicted: {0.285: '100%'}
# Actual: 19. Predicted: {0.38: '100%'}
# Actual: 23. Predicted: {0.3: '100%'}
# Actual: 23. Predicted: {0.075: '100%'}
# Actual: 8. Predicted: {0.245: '100%'}
# Actual: 14. Predicted: {0.1965: '100%'}
# Actual: 10. Predicted: {0.5660000000000001: '100%'}
# Actual: 18. Predicted: {0.1: '100%'}
# Actual: 6. Predicted: {0.21100000000000002: '100%'}
# Actual: 5. Predicted: {0.175: '100%'}
# Actual: 4. Predicted: {0.09: '100%'}
# Actual: 11. Predicted: {0.38: '100%'}
# Actual: 5. Predicted: {0.4165: '100%'}
# Actual: 7. Predicted: {0.675: '100%'}
# Actual: 7. Predicted: {0.335: '100%'}
# Actual: 7. Predicted: {0.27399999999999997: '100%'}
# Actual: 12. Predicted: {0.149: '100%'}
# Actual: 8. Predicted: {0.4: '100%'}
# Actual: 8. Predicted: {0.3055: '100%'}
# Actual: 12. Predicted: {0.175: '100%'}
# Actual: 8. Predicted: {0.185: '100%'}
# Actual: 5. Predicted: {0.57: '100%'}
# Actual: 5. Predicted: {0.27: '100%'}
# Actual: 16. Predicted: {0.345: '100%'}
# Actual: 11. Predicted: {0.111: '100%'}
# Actual: 14. Predicted: {0.0795: '100%'}
# Actual: 16. Predicted: {0.225: '100%'}
# Actual: 13. Predicted: {0.07: '100%'}
# Actual: 15. Predicted: {0.39: '100%'}
# Actual: 14. Predicted: {0.395: '100%'}
# Actual: 14. Predicted: {0.115: '100%'}
# Actual: 12. Predicted: {0.08: '100%'}
# Actual: 12. Predicted: {0.055: '100%'}
# Actual: 8. Predicted: {0.225: '100%'}
# Actual: 13. Predicted: {0.2675: '100%'}
# Actual: 9. Predicted: {0.09: '100%'}
# Actual: 6. Predicted: {0.055: '100%'}
# Actual: 8. Predicted: {0.29: '100%'}
# Actual: 14. Predicted: {0.188: '100%'}
# Actual: 8. Predicted: {0.109: '100%'}
# Actual: 22. Predicted: {0.025: '100%'}
# Actual: 12. Predicted: {0.35: '100%'}
# Actual: 9. Predicted: {0.115: '100%'}
# Actual: 16. Predicted: {0.1: '100%'}
# Actual: 20. Predicted: {0.431: '100%'}
# Actual: 13. Predicted: {0.125: '100%'}
# Actual: 18. Predicted: {0.07: '100%'}
# Actual: 17. Predicted: {0.4: '100%'}
# Actual: 16. Predicted: {0.15: '100%'}
# Actual: 18. Predicted: {0.083: '100%'}
# Actual: 12. Predicted: {0.0945: '100%'}
# Actual: 20. Predicted: {0.152: '100%'}
# Actual: 16. Predicted: {0.512: '100%'}
# Actual: 12. Predicted: {0.24: '100%'}
# Actual: 19. Predicted: {0.25: '100%'}
# Actual: 11. Predicted: {0.075: '100%'}
# Actual: 10. Predicted: {0.155: '100%'}
# Actual: 12. Predicted: {0.51: '100%'}
# Actual: 17. Predicted: {0.431: '100%'}
# Actual: 16. Predicted: {0.24: '100%'}
# Actual: 16. Predicted: {0.47: '100%'}
# Actual: 19. Predicted: {0.05: '100%'}
# Actual: 14. Predicted: {0.215: '100%'}
# Actual: 13. Predicted: {0.23399999999999999: '100%'}
# Actual: 20. Predicted: {0.209: '100%'}
# Actual: 11. Predicted: {0.11900000000000001: '100%'}
# Actual: 10. Predicted: {0.43200000000000005: '100%'}
# Actual: 15. Predicted: {0.25: '100%'}
# Actual: 12. Predicted: {0.155: '100%'}
# Actual: 15. Predicted: {0.3825: '100%'}
# Actual: 10. Predicted: {0.005: '100%'}
# Actual: 10. Predicted: {0.3935: '100%'}
# Actual: 12. Predicted: {0.046: '100%'}
# Actual: 10. Predicted: {0.109: '100%'}
# Actual: 9. Predicted: {0.2: '100%'}
# Actual: 12. Predicted: {0.0765: '100%'}
# Actual: 10. Predicted: {0.4: '100%'}
# Actual: 14. Predicted: {0.156: '100%'}
# Actual: 9. Predicted: {0.1825: '100%'}
# Actual: 10. Predicted: {0.075: '100%'}
# Actual: 10. Predicted: {0.295: '100%'}
# Actual: 10. Predicted: {0.4535: '100%'}
# Actual: 9. Predicted: {0.32: '100%'}
# Actual: 6. Predicted: {0.46: '100%'}
# Actual: 11. Predicted: {0.29: '100%'}
# Actual: 10. Predicted: {0.465: '100%'}
# Actual: 8. Predicted: {0.265: '100%'}
# Actual: 12. Predicted: {0.245: '100%'}
# Actual: 11. Predicted: {0.43: '100%'}
# Actual: 9. Predicted: {0.4715: '100%'}
# Actual: 9. Predicted: {0.065: '100%'}
# Actual: 7. Predicted: {0.515: '100%'}
# Actual: 10. Predicted: {0.406: '100%'}
# Actual: 7. Predicted: {0.264: '100%'}
# Actual: 12. Predicted: {0.14400000000000002: '100%'}
# Actual: 8. Predicted: {0.466: '100%'}
# Actual: 16. Predicted: {0.2065: '100%'}
# Actual: 11. Predicted: {0.275: '100%'}
# Actual: 8. Predicted: {0.35: '100%'}
# Actual: 15. Predicted: {0.021: '100%'}
# Actual: 14. Predicted: {0.03: '100%'}
# Actual: 11. Predicted: {0.24: '100%'}
# Actual: 12. Predicted: {0.46799999999999997: '100%'}
# Actual: 14. Predicted: {0.41: '100%'}
# Actual: 15. Predicted: {0.092: '100%'}
# Actual: 20. Predicted: {0.03: '100%'}
# Actual: 20. Predicted: {0.3945: '100%'}
# Actual: 16. Predicted: {0.045: '100%'}
# Actual: 13. Predicted: {0.245: '100%'}
# Actual: 14. Predicted: {0.034: '100%'}
# Actual: 11. Predicted: {0.09: '100%'}
# Actual: 13. Predicted: {0.185: '100%'}
# Actual: 8. Predicted: {0.0225: '100%'}
# Actual: 6. Predicted: {0.225: '100%'}
# Actual: 13. Predicted: {0.1395: '100%'}
# Actual: 18. Predicted: {0.162: '100%'}
# Actual: 19. Predicted: {0.32: '100%'}
# Actual: 21. Predicted: {0.13: '100%'}
# Actual: 18. Predicted: {0.08: '100%'}
# Actual: 18. Predicted: {0.13: '100%'}
# Actual: 20. Predicted: {0.375: '100%'}
# Actual: 18. Predicted: {0.083: '100%'}
# Actual: 22. Predicted: {0.33: '100%'}
# Actual: 13. Predicted: {0.29: '100%'}
# Actual: 11. Predicted: {0.25: '100%'}
# Actual: 7. Predicted: {0.15: '100%'}
# Actual: 14. Predicted: {0.055: '100%'}
# Actual: 9. Predicted: {0.095: '100%'}
# Actual: 13. Predicted: {0.4305: '100%'}
# Actual: 10. Predicted: {0.12300000000000001: '100%'}
# Actual: 8. Predicted: {0.15: '100%'}
# Actual: 19. Predicted: {0.095: '100%'}
# Actual: 10. Predicted: {0.146: '100%'}
# Actual: 10. Predicted: {0.126: '100%'}
# Actual: 9. Predicted: {0.23: '100%'}
# Actual: 13. Predicted: {0.35700000000000004: '100%'}
# Actual: 16. Predicted: {0.08199999999999999: '100%'}
# Actual: 12. Predicted: {0.445: '100%'}
# Actual: 18. Predicted: {0.2235: '100%'}
# Actual: 16. Predicted: {0.065: '100%'}
# Actual: 16. Predicted: {0.249: '100%'}
# Actual: 17. Predicted: {0.12: '100%'}
# Actual: 11. Predicted: {0.1: '100%'}
# Actual: 14. Predicted: {0.24: '100%'}
# Actual: 11. Predicted: {0.47100000000000003: '100%'}
# Actual: 15. Predicted: {0.115: '100%'}
# Actual: 9. Predicted: {0.1765: '100%'}
# Actual: 10. Predicted: {0.077: '100%'}
# Actual: 11. Predicted: {0.2325: '100%'}
# Actual: 11. Predicted: {0.215: '100%'}
# Actual: 12. Predicted: {0.26: '100%'}
# Actual: 6. Predicted: {0.49700000000000005: '100%'}
# Actual: 5. Predicted: {0.08: '100%'}
# Actual: 6. Predicted: {0.4: '100%'}
# Actual: 5. Predicted: {0.6095: '100%'}
# Actual: 12. Predicted: {0.28: '100%'}
# Actual: 13. Predicted: {0.35: '100%'}
# Actual: 17. Predicted: {0.336: '100%'}
# Actual: 21. Predicted: {0.43: '100%'}
# Actual: 9. Predicted: {0.3: '100%'}
# Actual: 10. Predicted: {0.215: '100%'}
# Actual: 9. Predicted: {0.3935: '100%'}
# Actual: 11. Predicted: {0.159: '100%'}
# Actual: 10. Predicted: {0.185: '100%'}
# Actual: 17. Predicted: {0.3085: '100%'}
# Actual: 9. Predicted: {0.2515: '100%'}
# Actual: 17. Predicted: {0.225: '100%'}
# Actual: 21. Predicted: {0.4165: '100%'}
# Actual: 16. Predicted: {0.005: '100%'}
# Actual: 29. Predicted: {0.174: '100%'}
# Actual: 17. Predicted: {0.265: '100%'}
# Actual: 15. Predicted: {0.24: '100%'}
# Actual: 19. Predicted: {0.16: '100%'}
# Actual: 12. Predicted: {0.358: '100%'}
# Actual: 13. Predicted: {0.285: '100%'}
# Actual: 11. Predicted: {0.5: '100%'}
# Actual: 15. Predicted: {0.335: '100%'}
# Actual: 11. Predicted: {0.25: '100%'}
# Actual: 14. Predicted: {0.385: '100%'}
# Actual: 14. Predicted: {0.365: '100%'}
# Actual: 13. Predicted: {0.18600000000000003: '100%'}
# Actual: 11. Predicted: {0.25: '100%'}
# Actual: 15. Predicted: {0.035: '100%'}
# Actual: 17. Predicted: {0.1005: '100%'}
# Actual: 15. Predicted: {0.28: '100%'}
# Actual: 12. Predicted: {0.225: '100%'}
# Actual: 19. Predicted: {0.085: '100%'}
# Actual: 11. Predicted: {0.235: '100%'}
# Actual: 10. Predicted: {0.263: '100%'}
# Actual: 12. Predicted: {0.068: '100%'}
# Actual: 23. Predicted: {0.035: '100%'}
# Actual: 15. Predicted: {0.295: '100%'}
# Actual: 13. Predicted: {0.336: '100%'}
# Actual: 17. Predicted: {0.2565: '100%'}
# Actual: 15. Predicted: {0.075: '100%'}
# Actual: 12. Predicted: {0.26: '100%'}
# Actual: 15. Predicted: {0.3095: '100%'}
# Actual: 11. Predicted: {0.16: '100%'}
# Actual: 16. Predicted: {0.192: '100%'}
# Actual: 10. Predicted: {0.18: '100%'}
# Actual: 10. Predicted: {0.2155: '100%'}
# Actual: 10. Predicted: {0.22: '100%'}
# Actual: 6. Predicted: {0.1375: '100%'}
# Actual: 5. Predicted: {0.3275: '100%'}
# Actual: 6. Predicted: {0.07: '100%'}
# Actual: 9. Predicted: {0.26: '100%'}
# Actual: 5. Predicted: {0.175: '100%'}
# Actual: 4. Predicted: {0.555: '100%'}
# Actual: 6. Predicted: {0.125: '100%'}
# Actual: 3. Predicted: {0.094: '100%'}
# Actual: 5. Predicted: {0.345: '100%'}
# Actual: 9. Predicted: {0.19399999999999998: '100%'}
# Actual: 5. Predicted: {0.1525: '100%'}
# Actual: 4. Predicted: {0.047: '100%'}
# Actual: 4. Predicted: {0.12: '100%'}
# Actual: 3. Predicted: {0.37200000000000005: '100%'}
# Actual: 14. Predicted: {0.125: '100%'}
# Actual: 12. Predicted: {0.49: '100%'}
# Actual: 9. Predicted: {0.2825: '100%'}
# Actual: 20. Predicted: {0.474: '100%'}
# Actual: 13. Predicted: {0.2665: '100%'}
# Actual: 12. Predicted: {0.174: '100%'}
# Actual: 9. Predicted: {0.2485: '100%'}
# Actual: 10. Predicted: {0.405: '100%'}
# Actual: 11. Predicted: {0.139: '100%'}
# Actual: 11. Predicted: {0.14800000000000002: '100%'}
# Actual: 7. Predicted: {0.145: '100%'}
# Actual: 5. Predicted: {0.35: '100%'}
# Actual: 10. Predicted: {0.42: '100%'}
# Actual: 15. Predicted: {0.33: '100%'}
# Actual: 11. Predicted: {0.3225: '100%'}
# Actual: 15. Predicted: {0.5235: '100%'}
# Actual: 8. Predicted: {0.2825: '100%'}
# Actual: 10. Predicted: {0.4285: '100%'}
# Actual: 11. Predicted: {0.4275: '100%'}
# Actual: 8. Predicted: {0.5365: '100%'}
# Actual: 7. Predicted: {0.039: '100%'}
# Actual: 12. Predicted: {0.262: '100%'}
# Actual: 11. Predicted: {0.1485: '100%'}
# Actual: 17. Predicted: {0.1475: '100%'}
# Actual: 13. Predicted: {0.21: '100%'}
# Actual: 12. Predicted: {0.065: '100%'}
# Actual: 13. Predicted: {0.0095: '100%'}
# Actual: 9. Predicted: {0.14: '100%'}
# Actual: 10. Predicted: {0.34: '100%'}
# Actual: 14. Predicted: {0.7: '100%'}
# Actual: 12. Predicted: {0.4075: '100%'}
# Actual: 13. Predicted: {0.2845: '100%'}
# Actual: 13. Predicted: {0.0725: '100%'}
# Actual: 8. Predicted: {0.12: '100%'}
# Actual: 13. Predicted: {0.228: '100%'}
# Actual: 11. Predicted: {0.36: '100%'}
# Actual: 11. Predicted: {0.57: '100%'}
# Actual: 14. Predicted: {0.47100000000000003: '100%'}
# Actual: 10. Predicted: {0.04: '100%'}
# Actual: 12. Predicted: {0.405: '100%'}
# Actual: 12. Predicted: {0.3: '100%'}
# Actual: 7. Predicted: {0.0925: '100%'}
# Actual: 11. Predicted: {0.2285: '100%'}
# Actual: 16. Predicted: {0.01: '100%'}
# Actual: 14. Predicted: {0.32299999999999995: '100%'}
# Actual: 20. Predicted: {0.26: '100%'}
# Actual: 17. Predicted: {0.204: '100%'}
# Actual: 10. Predicted: {0.045: '100%'}
# Actual: 11. Predicted: {0.06: '100%'}
# Actual: 10. Predicted: {0.125: '100%'}
# Actual: 10. Predicted: {0.28: '100%'}
# Actual: 11. Predicted: {0.09: '100%'}
# Actual: 17. Predicted: {0.196: '100%'}
# Actual: 11. Predicted: {0.095: '100%'}
# Actual: 14. Predicted: {0.0345: '100%'}
# Actual: 19. Predicted: {0.01: '100%'}
# Actual: 13. Predicted: {0.3345: '100%'}
# Actual: 11. Predicted: {0.175: '100%'}
# Actual: 11. Predicted: {0.086: '100%'}
# Actual: 10. Predicted: {0.07: '100%'}
# Actual: 13. Predicted: {0.12: '100%'}
# Actual: 14. Predicted: {0.185: '100%'}
# Actual: 13. Predicted: {0.225: '100%'}
# Actual: 13. Predicted: {0.254: '100%'}
# Actual: 9. Predicted: {0.32: '100%'}
# Actual: 18. Predicted: {0.1675: '100%'}
# Actual: 19. Predicted: {0.317: '100%'}
# Actual: 12. Predicted: {0.3095: '100%'}
# Actual: 13. Predicted: {0.141: '100%'}
# Actual: 9. Predicted: {0.25: '100%'}
# Actual: 13. Predicted: {0.3185: '100%'}
# Actual: 12. Predicted: {0.1125: '100%'}
# Actual: 16. Predicted: {0.5015: '100%'}
# Actual: 17. Predicted: {0.2505: '100%'}
# Actual: 10. Predicted: {0.223: '100%'}
# Actual: 13. Predicted: {0.358: '100%'}
# Actual: 11. Predicted: {0.321: '100%'}
# Actual: 12. Predicted: {0.354: '100%'}
# Actual: 13. Predicted: {0.345: '100%'}
# Actual: 9. Predicted: {0.13: '100%'}
# Actual: 10. Predicted: {0.29600000000000004: '100%'}
# Actual: 10. Predicted: {0.35: '100%'}
# Actual: 12. Predicted: {0.235: '100%'}
# Actual: 12. Predicted: {0.341: '100%'}
# Actual: 4. Predicted: {0.157: '100%'}
# Actual: 9. Predicted: {0.1: '100%'}
# Actual: 18. Predicted: {0.40700000000000003: '100%'}
# Actual: 15. Predicted: {0.125: '100%'}
# Actual: 13. Predicted: {0.16699999999999998: '100%'}
# Actual: 12. Predicted: {0.1825: '100%'}
# Actual: 7. Predicted: {0.12: '100%'}
# Actual: 9. Predicted: {0.08199999999999999: '100%'}
# Actual: 7. Predicted: {0.113: '100%'}
# Actual: 10. Predicted: {0.1305: '100%'}
# Actual: 18. Predicted: {0.06: '100%'}
# Actual: 12. Predicted: {0.05: '100%'}
# Actual: 17. Predicted: {0.2235: '100%'}
# Actual: 15. Predicted: {0.025: '100%'}
# Actual: 12. Predicted: {0.245: '100%'}
# Actual: 10. Predicted: {0.885: '100%'}
# Actual: 8. Predicted: {0.21: '100%'}
# Actual: 21. Predicted: {0.01: '100%'}
# Actual: 10. Predicted: {0.3085: '100%'}
# Actual: 9. Predicted: {0.385: '100%'}
# Actual: 7. Predicted: {0.1835: '100%'}
# Actual: 10. Predicted: {0.425: '100%'}
# Actual: 9. Predicted: {0.315: '100%'}
# Actual: 9. Predicted: {0.155: '100%'}
# Actual: 8. Predicted: {0.32: '100%'}
# Actual: 7. Predicted: {0.159: '100%'}
# Actual: 6. Predicted: {0.147: '100%'}
# Actual: 14. Predicted: {0.36: '100%'}
# Actual: 13. Predicted: {0.077: '100%'}
# Actual: 7. Predicted: {0.17: '100%'}
# Actual: 13. Predicted: {0.035: '100%'}
# Actual: 19. Predicted: {0.255: '100%'}
# Actual: 7. Predicted: {0.455: '100%'}
# Actual: 9. Predicted: {0.201: '100%'}
# Actual: 11. Predicted: {0.259: '100%'}
# Actual: 6. Predicted: {0.265: '100%'}
# Actual: 9. Predicted: {0.185: '100%'}
# Actual: 11. Predicted: {0.295: '100%'}
# Actual: 9. Predicted: {0.335: '100%'}
# Actual: 5. Predicted: {0.2505: '100%'}
# Actual: 6. Predicted: {0.0575: '100%'}
# Actual: 11. Predicted: {0.345: '100%'}
# Actual: 7. Predicted: {0.08199999999999999: '100%'}
# Actual: 10. Predicted: {0.185: '100%'}
# Actual: 7. Predicted: {0.193: '100%'}
# Actual: 17. Predicted: {0.20199999999999999: '100%'}
# Actual: 16. Predicted: {0.19: '100%'}
# Actual: 18. Predicted: {0.109: '100%'}
# Actual: 11. Predicted: {0.295: '100%'}
# Actual: 18. Predicted: {0.425: '100%'}
# Actual: 11. Predicted: {0.07: '100%'}
# Actual: 10. Predicted: {0.207: '100%'}
# Actual: 12. Predicted: {0.255: '100%'}
# Actual: 19. Predicted: {0.2055: '100%'}
# Actual: 10. Predicted: {0.3: '100%'}
# Actual: 11. Predicted: {0.34: '100%'}
# Actual: 15. Predicted: {0.354: '100%'}
# Actual: 13. Predicted: {0.065: '100%'}
# Actual: 13. Predicted: {0.3375: '100%'}
# Actual: 14. Predicted: {0.48200000000000004: '100%'}
# Actual: 17. Predicted: {0.39799999999999996: '100%'}
# Actual: 19. Predicted: {0.31: '100%'}
# Actual: 21. Predicted: {0.31: '100%'}
# Actual: 23. Predicted: {0.055: '100%'}
# Actual: 22. Predicted: {0.05: '100%'}
# Actual: 12. Predicted: {0.1955: '100%'}
# Actual: 11. Predicted: {0.17: '100%'}
# Actual: 23. Predicted: {0.345: '100%'}
# Actual: 8. Predicted: {0.0245: '100%'}
# Actual: 7. Predicted: {0.355: '100%'}
# Actual: 10. Predicted: {0.07: '100%'}
# Actual: 7. Predicted: {0.49: '100%'}
# Actual: 16. Predicted: {0.2035: '100%'}
# Actual: 10. Predicted: {0.0735: '100%'}
# Actual: 15. Predicted: {0.149: '100%'}
# Actual: 13. Predicted: {0.042: '100%'}
# Actual: 16. Predicted: {0.17: '100%'}
# Actual: 11. Predicted: {0.225: '100%'}
# Actual: 11. Predicted: {0.435: '100%'}
# Actual: 10. Predicted: {0.13: '100%'}
# Actual: 5. Predicted: {0.17: '100%'}
# Actual: 11. Predicted: {0.405: '100%'}
# Actual: 9. Predicted: {0.185: '100%'}
# Actual: 4. Predicted: {0.22: '100%'}
# Actual: 7. Predicted: {0.2605: '100%'}
# Actual: 4. Predicted: {0.253: '100%'}
# Actual: 5. Predicted: {0.435: '100%'}
# Actual: 13. Predicted: {0.166: '100%'}
# Actual: 16. Predicted: {0.147: '100%'}
# Actual: 12. Predicted: {0.185: '100%'}
# Actual: 14. Predicted: {0.004: '100%'}
# Actual: 9. Predicted: {0.1825: '100%'}
# Actual: 12. Predicted: {0.1985: '100%'}
# Actual: 9. Predicted: {0.325: '100%'}
# Actual: 10. Predicted: {0.22899999999999998: '100%'}
# Actual: 11. Predicted: {0.29600000000000004: '100%'}
# Actual: 10. Predicted: {0.294: '100%'}
# Actual: 10. Predicted: {0.35700000000000004: '100%'}
# Actual: 7. Predicted: {0.15: '100%'}
# Actual: 7. Predicted: {0.17: '100%'}
# Actual: 11. Predicted: {0.259: '100%'}
# Actual: 7. Predicted: {0.039: '100%'}
# Actual: 8. Predicted: {0.365: '100%'}
# Actual: 9. Predicted: {0.3225: '100%'}
# Actual: 7. Predicted: {0.3315: '100%'}
# Actual: 8. Predicted: {0.018000000000000002: '100%'}
# Actual: 6. Predicted: {0.2915: '100%'}
# Actual: 4. Predicted: {0.09: '100%'}
# Actual: 2. Predicted: {0.3395: '100%'}
# Actual: 3. Predicted: {0.231: '100%'}
# Actual: 13. Predicted: {0.184: '100%'}
# Actual: 15. Predicted: {0.27399999999999997: '100%'}
# Actual: 15. Predicted: {0.4165: '100%'}
# Actual: 11. Predicted: {0.175: '100%'}
# Actual: 17. Predicted: {0.094: '100%'}
# Actual: 10. Predicted: {0.395: '100%'}
# Actual: 12. Predicted: {0.1625: '100%'}
# Actual: 13. Predicted: {0.295: '100%'}
# Actual: 15. Predicted: {0.495: '100%'}
# Actual: 11. Predicted: {0.3: '100%'}
# Actual: 13. Predicted: {0.15: '100%'}
# Actual: 15. Predicted: {0.1485: '100%'}
# Actual: 13. Predicted: {0.2885: '100%'}
# Actual: 18. Predicted: {0.5015: '100%'}
# Actual: 10. Predicted: {0.31: '100%'}
# Actual: 12. Predicted: {0.34700000000000003: '100%'}
# Actual: 12. Predicted: {0.025: '100%'}
# Actual: 14. Predicted: {0.3275: '100%'}
# Actual: 10. Predicted: {0.4325: '100%'}
# Actual: 14. Predicted: {0.255: '100%'}
# Actual: 8. Predicted: {0.295: '100%'}
# Actual: 14. Predicted: {0.043: '100%'}
# Actual: 17. Predicted: {0.0245: '100%'}
# Actual: 20. Predicted: {0.025: '100%'}
# Actual: 17. Predicted: {0.425: '100%'}
# Actual: 17. Predicted: {0.115: '100%'}
# Actual: 9. Predicted: {0.2475: '100%'}
# Actual: 14. Predicted: {0.135: '100%'}
# Actual: 15. Predicted: {0.395: '100%'}
# Actual: 13. Predicted: {0.275: '100%'}
# Actual: 10. Predicted: {0.255: '100%'}
# Actual: 13. Predicted: {0.215: '100%'}
# Actual: 13. Predicted: {0.3: '100%'}
# Actual: 20. Predicted: {0.295: '100%'}
# Actual: 13. Predicted: {0.28: '100%'}
# Actual: 20. Predicted: {0.12300000000000001: '100%'}
# Actual: 15. Predicted: {0.35: '100%'}
# Actual: 13. Predicted: {0.18100000000000002: '100%'}
# Actual: 15. Predicted: {0.1555: '100%'}
# Actual: 15. Predicted: {0.17: '100%'}
# Actual: 16. Predicted: {0.185: '100%'}
# Actual: 17. Predicted: {0.113: '100%'}
# Actual: 14. Predicted: {0.195: '100%'}
# Actual: 14. Predicted: {0.09: '100%'}
# Actual: 11. Predicted: {0.0105: '100%'}
# Actual: 13. Predicted: {0.245: '100%'}
# Actual: 9. Predicted: {0.27: '100%'}
# Actual: 11. Predicted: {0.49: '100%'}
# Actual: 17. Predicted: {0.295: '100%'}
# Actual: 11. Predicted: {0.06: '100%'}
# Actual: 8. Predicted: {0.18: '100%'}
# Actual: 8. Predicted: {0.188: '100%'}
# Actual: 9. Predicted: {0.2835: '100%'}
# Actual: 10. Predicted: {0.225: '100%'}
# Actual: 11. Predicted: {0.28: '100%'}
# Actual: 15. Predicted: {0.17: '100%'}
# Actual: 13. Predicted: {0.24: '100%'}
# Actual: 15. Predicted: {0.2735: '100%'}
# Actual: 15. Predicted: {0.11: '100%'}
# Actual: 13. Predicted: {0.013999999999999999: '100%'}
# Actual: 12. Predicted: {0.34: '100%'}
# Actual: 10. Predicted: {0.07: '100%'}
# Actual: 6. Predicted: {0.28600000000000003: '100%'}
# Actual: 5. Predicted: {0.325: '100%'}
# Actual: 15. Predicted: {0.062: '100%'}
# Actual: 9. Predicted: {0.035: '100%'}
# Actual: 12. Predicted: {0.35: '100%'}
# Actual: 9. Predicted: {0.503: '100%'}
# Actual: 12. Predicted: {0.27: '100%'}
# Actual: 10. Predicted: {0.285: '100%'}
# Actual: 10. Predicted: {0.077: '100%'}
# Actual: 9. Predicted: {0.3185: '100%'}
# Actual: 12. Predicted: {0.5529999999999999: '100%'}
# Actual: 12. Predicted: {0.36: '100%'}
# Actual: 15. Predicted: {0.295: '100%'}
# Actual: 11. Predicted: {0.2285: '100%'}
# Actual: 9. Predicted: {0.0575: '100%'}
# Actual: 11. Predicted: {0.3175: '100%'}
# Actual: 11. Predicted: {0.195: '100%'}
# Actual: 10. Predicted: {0.133: '100%'}
# Actual: 10. Predicted: {0.145: '100%'}
# Actual: 9. Predicted: {0.145: '100%'}
# Actual: 7. Predicted: {0.295: '100%'}
# Actual: 10. Predicted: {0.07: '100%'}
# Actual: 7. Predicted: {0.575: '100%'}
# Actual: 6. Predicted: {0.08199999999999999: '100%'}
# Actual: 15. Predicted: {0.07: '100%'}
# Actual: 10. Predicted: {0.215: '100%'}
# Actual: 12. Predicted: {0.2645: '100%'}
# Actual: 12. Predicted: {0.2325: '100%'}
# Actual: 21. Predicted: {0.121: '100%'}
# Actual: 6. Predicted: {0.336: '100%'}
# Actual: 5. Predicted: {0.365: '100%'}
# Actual: 7. Predicted: {0.12: '100%'}
# Actual: 7. Predicted: {0.225: '100%'}
# Actual: 6. Predicted: {0.3315: '100%'}
# Actual: 6. Predicted: {0.275: '100%'}
# Actual: 6. Predicted: {0.06: '100%'}
# Actual: 7. Predicted: {0.5: '100%'}
# Actual: 7. Predicted: {0.040999999999999995: '100%'}
# Actual: 6. Predicted: {0.475: '100%'}
# Actual: 7. Predicted: {0.1405: '100%'}
# Actual: 6. Predicted: {0.28: '100%'}
# Actual: 7. Predicted: {0.18: '100%'}
# Actual: 7. Predicted: {0.26899999999999996: '100%'}
# Actual: 6. Predicted: {0.435: '100%'}
# Actual: 6. Predicted: {0.146: '100%'}
# Actual: 6. Predicted: {0.34: '100%'}
# Actual: 7. Predicted: {0.145: '100%'}
# Actual: 6. Predicted: {0.355: '100%'}
# Actual: 6. Predicted: {0.275: '100%'}
# Actual: 9. Predicted: {0.285: '100%'}
# Actual: 7. Predicted: {0.18: '100%'}
# Actual: 7. Predicted: {0.15: '100%'}
# Actual: 8. Predicted: {0.26: '100%'}
# Actual: 8. Predicted: {0.365: '100%'}
